# %%
import pandas as pd

# %%
df1 = pd.read_csv("dataRevolve/flights.csv")

# %%
df1
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     544.0       -1.0    1004.0      -18.0      B6
# 4       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 336771  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336772  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336773  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336774  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336775  2013      9   30       NaN        NaN       NaN        NaN      MQ
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
df1["date"] = pd.to_datetime((df1.year*10000+df1.month*100+df1.day),format = "%Y%m%d")

# %%
df1
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     544.0       -1.0    1004.0      -18.0      B6
# 4       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 336771  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336772  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336773  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336774  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336775  2013      9   30       NaN        NaN       NaN        NaN      MQ
#
# ...

# %%
print(df1.date.value_counts().count(), 'is the total number of days covered in the dataset')
# Out:
# 365 is the total number of days covered in the dataset

# %% [markdown]
# ## 365 is the total number of days covered in the dataset

# %%
df2 = pd.read_csv("dataRevolve/airports.csv")

# %%
df2
# Out:
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# ...

# %%
print(df2.CITY.value_counts().count(), 'is the total number of city')
# Out:
# 308 is the total number of city

# %% [markdown]
# ## 308 is the total number of city

# %%
df3 = pd.read_csv('dataRevolve/planes.csv')

# %%
df3
# Out:
#      tailnum    year                     type                   manufacturer  \
# 0     N10156  2004.0  Fixed wing multi engine                        EMBRAER
# 1     N102UW  1998.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 2     N103US  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 3     N104UW  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 4     N10575  2002.0  Fixed wing multi engine                        EMBRAER
# ...      ...     ...                      ...                            ...
# 3317  N997AT  2002.0  Fixed wing multi engine                         BOEING
# 3318  N997DL  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS AIRCRAFT CO
# 3319  N998AT  2002.0  Fixed wing multi engine                         BOEING
# 3320  N998DL  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
# 3321  N999DN  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
#
# ...

# %%
df1
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     544.0       -1.0    1004.0      -18.0      B6
# 4       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 336771  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336772  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336773  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336774  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336775  2013      9   30       NaN        NaN       NaN        NaN      MQ
#
# ...

# %% [markdown]
# ## we can see that the both columns contain a same column, tailnum it is the number of the plane's tail number and the flights datasets indicates which plane is going to which destination at what time and date
#
# ## we can merge the data on that column to see the deatils of the flying plane with the tailnum

# %%
df1[df1['dep_delay']>0].tailnum.value_counts()
# Out:
# N258JB    186
# N228JB    165
# N15980    158
# N190JB    157
# N725MQ    152
#          ...
# N363SW      1
# N7ASAA      1
# N646UA      1
# N59630      1
# N512SW      1
# Name: tailnum, Length: 3885, dtype: int64

# %% [markdown]
# # here we can see that the N258JB tailnum has the most delay now we have to find its manufacturer

# %%
df3[df3['tailnum']=='N258JB'].manufacturer
# Out:
# 543    EMBRAER
# Name: manufacturer, dtype: object

# %% [markdown]
# ### EMBRAER manufacturer is the most delays in the analysis period

# %%
df1.dest.value_counts()
# Out:
# ORD    17283
# ATL    17215
# LAX    16174
# BOS    15508
# MCO    14082
#        ...
# MTJ       15
# SBN       10
# ANC        8
# LGA        1
# LEX        1
# Name: dest, Length: 105, dtype: int64

# %%
df1
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     544.0       -1.0    1004.0      -18.0      B6
# 4       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 336771  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336772  2013      9   30       NaN        NaN       NaN        NaN      9E
# 336773  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336774  2013      9   30       NaN        NaN       NaN        NaN      MQ
# 336775  2013      9   30       NaN        NaN       NaN        NaN      MQ
#
# ...

# %%
df2[df2['IATA_CODE']=='EWR']
# Out:
#     IATA_CODE                               AIRPORT    CITY STATE COUNTRY  \
# 106       EWR  Newark Liberty International Airport  Newark    NJ     USA
#
#      LATITUDE  LONGITUDE
# 106   40.6925  -74.16866

# %%
df1[df1['origin']=='EWR']
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 5       2013      1    1     554.0       -4.0     740.0       12.0      UA
# 6       2013      1    1     555.0       -5.0     913.0       19.0      B6
# 13      2013      1    1     558.0       -2.0     923.0      -14.0      UA
# 16      2013      1    1     559.0       -1.0     854.0       -8.0      UA
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 336752  2013      9   30    2142.0       13.0    2250.0       11.0      EV
# 336755  2013      9   30    2149.0       -7.0    2245.0      -23.0      UA
# 336756  2013      9   30    2150.0       -9.0    2250.0      -16.0      EV
# 336760  2013      9   30    2211.0       72.0    2339.0       57.0      EV
# 336762  2013      9   30    2233.0       80.0     112.0       42.0      UA
#
# ...

# %%
df2
# Out:
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# ...

# %%
df2.IATA_CODE.value_counts()
# Out:
# ISN    1
# MKE    1
# ISP    1
# CLD    1
# LAR    1
#       ..
# PPG    1
# FAT    1
# SHV    1
# BNA    1
# BTV    1
# Name: IATA_CODE, Length: 322, dtype: int64

# %%
df1.value_counts(df1['dest'])
# Out:
# dest
# ORD    17283
# ATL    17215
# LAX    16174
# BOS    15508
# MCO    14082
#        ...
# HDN       15
# SBN       10
# ANC        8
# LGA        1
# LEX        1
# Length: 105, dtype: int64

# %%
df1.value_counts(df1['origin'])
# Out:
# origin
# EWR    120835
# JFK    111279
# LGA    104662
# dtype: int64

# %%
 df1.groupby(['dest','origin']).size().sort_values()
# Out:
# dest  origin
# MEM   JFK           1
# LGA   EWR           1
# BHM   JFK           1
# STL   JFK           1
# LEX   LGA           1
#                 ...
# CLT   LGA        6168
# SFO   JFK        8204
# ORD   LGA        8857
# ATL   LGA       10263
# LAX   JFK       11262
# Length: 224, dtype: int64

# %% [markdown]
# ## Here we can see LAX and JFK has the most number of flights which indicates there are the most connected

# %%
df2[df2['IATA_CODE']=='LAX']
# Out:
#     IATA_CODE                            AIRPORT         CITY STATE COUNTRY  \
# 176       LAX  Los Angeles International Airport  Los Angeles    CA     USA
#
#      LATITUDE  LONGITUDE
# 176  33.94254 -118.40807

# %%
df2[df2['IATA_CODE']=='JFK']
# Out:
#     IATA_CODE                                            AIRPORT      CITY  \
# 166       JFK  John F. Kennedy International Airport (New Yor...  New York
#
#     STATE COUNTRY  LATITUDE  LONGITUDE
# 166    NY     USA  40.63975  -73.77893

# %% [markdown]
# ## NEW YORK and LOS ANGELES are the two most connected cities
